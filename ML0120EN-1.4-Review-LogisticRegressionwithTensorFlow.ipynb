# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/qo20b88v1hbjztubt06609ovs85q8fau.png" width="400px"  align="center"></a>
# <h1 align="center"><font size="5">LOGISTIC REGRESSION WITH TENSORFLOW</font></h1>

# %% [markdown]
# ## Table of Contents
#
# Logistic Regression is one of most important techniques in data science. It is usually used to solve the classic classification problem.
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size = 3><strong>This lesson covers the following concepts of Logistics Regression:</strong></font>
# <br>
# <h2>Table of Contents</h2>
#
# <ol>
#     <li><a href="#ref1">Linear Regression vs Logistic Regression</a></li>
#     <li><a href="#ref2">Utilizing Logistic Regression in TensorFlow</a></li>
#     <li><a href="#ref3">Training</a></li>
# </ol>
# </div>
# <p></p>
# <br>
#
# <hr>

# %% [markdown]
# <a id="ref1"></a>
# <h2>What is different between Linear and Logistic Regression?</h2>
#
# While Linear Regression is suited for estimating continuous values (e.g. estimating house price), it is n0t the best tool for predicting the class in which an observed data point belongs. In order to provide estimate for classification, we need some sort of guidance on what would be the <b>most probable class</b> for that data point. For this, we use <b>Logistic Regression</b>.
#
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# <font size="3"><strong>Recall linear regression:</strong></font>
# <br>
# <br>
# Linear regression finds a function that relates a continuous dependent variable, <i>y</i>, to some predictors (independent variables <i>x1</i>, <i>x2</i>, etc.). Simple linear regression assumes a function of the form:
# <br><br>
# $$
# y = w0 + w1 \times x1 + w2 \times x2 + \cdots
# $$
# <br>
# and finds the values of <i>w0</i>, <i>w1</i>, <i>w2</i>, etc. The term <i>w0</i> is the "intercept" or "constant term" (it's shown as <i>b</i> in the formula below):
# <br><br>
# $$
# Y = W X + b
# $$
# <p></p>
#
# </div>
#
# Logistic Regression is a variation of Linear Regression, useful when the observed dependent variable, <i>y</i>, is categorical. It produces a formula that predicts the probability of the class label as a function of the independent variables.
#
# Despite the name logistic <i>regression</i>, it is actually a <b>probabilistic classification</b> model. Logistic regression fits a special s-shaped curve by taking the linear regression and transforming the numeric estimate into a probability with the following function:
#
# $$
# ProbabilityOfaClass = \theta(y) = \frac{e^y}{1 + e^y} = exp(y) / (1 + exp(y)) = p
# $$
#
# which produces p-values between 0 (as y approaches minus infinity $-\infty$) and 1 (as y approaches plus infinity $+\infty$). This now becomes a special kind of non-linear regression.
#
# In this equation, <i>y</i> is the regression result (the sum of the variables weighted by the coefficients), <code>exp</code> is the exponential function and $\theta(y)$ is the <a href="http://en.wikipedia.org/wiki/Logistic_function">logistic function</a>, also called logistic curve. It is a common "S" shape (sigmoid curve), and was first developed for modeling population growth.
#
# You might also have seen this function before, in another configuration:
#
# $$
# ProbabilityOfaClass = \theta(y) = \frac{1}{1+e^{-y}}
# $$
#
# So, briefly, Logistic Regression passes the input through the logistic/sigmoid function but then treats the result as a probability:
#
# <img src="https://ibm.box.com/shared/static/kgv9alcghmjcv97op4d6onkyxevk23b1.png" width="400" align="center">

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a id="ref2"></a>
# <h2>Utilizing Logistic Regression in TensorFlow</h2>
#
# For us to utilize Logistic Regression in TensorFlow, we first need to import the required libraries. To do so, you can run the code cell below.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import time
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we will load the dataset we are going to use. In this case, we are utilizing the <code>iris</code> dataset, which is inbuilt -- so there's no need to do any preprocessing and we can jump right into manipulating it. We separate the dataset into <i>xs</i> and <i>ys</i>, and then into training <i>xs</i> and <i>ys</i> and testing <i>xs</i> and <i>ys</i>, (pseudo)randomly.

# %% [markdown]
# <h3>Understanding the Data</h3>
#
# <h4><code>Iris Dataset</code>:</h4>
# This dataset was introduced by British Statistician and Biologist Ronald Fisher, it consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). In total it has 150 records under five attributes - petal length, petal width, sepal length, sepal width and species. <a href="https://archive.ics.uci.edu/ml/datasets/iris">Dataset source</a>
#
# Attributes
# Independent Variable
# <ul>
#     <li>petal length</li>
#     <li>petal width</li>
#     <li>sepal length</li>
#     <li>sepal width</li>
# </ul>
# Dependent Variable
# <ul>
#     <li>Species
#         <ul>
#             <li>Iris setosa</li>
#             <li>Iris virginica</li>
#             <li>Iris versicolor</li>
#         </ul>
#     </li>
# </ul>
# <br>

# %%
iris = load_iris()
iris_X, iris_y = iris.data[:-1,:], iris.target[:-1]
iris_y= pd.get_dummies(iris_y).values
trainX, testX, trainY, testY = train_test_split(iris_X, iris_y, test_size=0.33, random_state=42)

# %% [markdown]
# Now we define x and y. These placeholders will hold our iris data (both the features and label matrices), and help pass them along to different parts of the algorithm. You can consider placeholders as empty shells into which we insert our data. We also need to give them shapes which correspond to the shape of our data. Later, we will insert data into these placeholders by “feeding” the placeholders the data via a “feed_dict” (Feed Dictionary).
#
# <h3>Why use Placeholders?</h3>
#
# <ol>
#     <li>This feature of TensorFlow allows us to create an algorithm which accepts data and knows something about the shape of the data without knowing the amount of data going in.</li>
#     <li>When we insert “batches” of data in training, we can easily adjust how many examples we train on in a single step without changing the entire algorithm.</li>
# </ol>

# %%
# numFeatures is the number of features in our input data.
# In the iris dataset, this number is '4'.
numFeatures = trainX.shape[1]

# numLabels is the number of classes our data points can be in.
# In the iris dataset, this number is '3'.
numLabels = trainY.shape[1]


# Placeholders
# 'None' means TensorFlow shouldn't expect a fixed number in that dimension
X = tf.placeholder(tf.float32, [None, numFeatures]) # Iris has 4 features, so X is a tensor to hold our data.
yGold = tf.placeholder(tf.float32, [None, numLabels]) # This will be our correct answers matrix for 3 classes.

# %% [markdown]
# <h3>Set model weights and bias</h3>
#
# Much like Linear Regression, we need a shared variable weight matrix for Logistic Regression. We initialize both <code>W</code> and <code>b</code> as tensors full of zeros. Since we are going to learn <code>W</code> and <code>b</code>, their initial value does not matter too much. These variables are the objects which define the structure of our regression model, and we can save them after they have been trained so we can reuse them later.
#
# We define two TensorFlow variables as our parameters. These variables will hold the weights and biases of our logistic regression and they will be continually updated during training.
#
# Notice that <code>W</code> has a shape of [4, 3] because we want to multiply the 4-dimensional input vectors by it to produce 3-dimensional vectors of evidence for the difference classes. <code>b</code> has a shape of [3] so we can add it to the output. Moreover, unlike our placeholders above which are essentially empty shells waiting to be fed data, TensorFlow variables need to be initialized with values, e.g. with zeros.

# %%
W = tf.Variable(tf.zeros([4, 3]))  # 4-dimensional input and  3 classes
b = tf.Variable(tf.zeros([3])) # 3-dimensional output [0,0,1],[0,1,0],[1,0,0]

# %%
#Randomly sample from a normal distribution with standard deviation .01

weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=0.01,
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=0.01,
                                    name="bias"))

# %% [markdown]
# <h3>Logistic Regression model</h3>
#
# We now define our operations in order to properly run the Logistic Regression. Logistic regression is typically thought of as a single equation:
#
# $$
# ŷ =sigmoid(WX+b)
# $$
#
# However, for the sake of clarity, we can have it broken into its three main components:
# - a weight times features matrix multiplication operation,
# - a summation of the weighted features and a bias term,
# - and finally the application of a sigmoid function.
#
# As such, you will find these components defined as three separate operations below.

# %%
# Three-component breakdown of the Logistic Regression equation.
# Note that these feed into each other.
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias") 
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# %% [markdown]
# As we have seen before, the function we are going to use is the <i>logistic function</i> $(\frac{1}{1+e^{-Wx}})$, which is fed the input data after applying weights and bias. In TensorFlow, this function is implemented as the <code>nn.sigmoid</code> function. Effectively, this fits the weighted input with bias into a 0-100 percent curve, which is the probability function we want.

# %% [markdown]
# <hr>

# %% [markdown]
# <a id="ref3"></a>
# <h2>Training</h2>
#
# The learning algorithm is how we search for the best weight vector (${\bf w}$). This search is an optimization problem looking for the hypothesis that optimizes an error/cost measure.
#
# <b>What tell us our model is bad?</b>
# The Cost or Loss of the model, so what we want is to minimize that.
#
# <b>What is the cost function in our model?</b>
# The cost function we are going to utilize is the Squared Mean Error loss function.
#
# <b>How to minimize the cost function?</b>
# We can't use <b>least-squares linear regression</b> here, so we will use <a href="http://en.wikipedia.org/wiki/Gradient_descent">gradient descent</a> instead. Specifically, we will use batch gradient descent which calculates the gradient from all data points in the data set.
#
# <h3>Cost function</h3>
# Before defining our cost function, we need to define how long we are going to train and how should we define the learning rate.

# %%
# Number of Epochs in our training
numEpochs = 7000

# Defining our learning rate iterations (decay)
learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

# %%
#Defining our cost function - Squared Mean Error
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

#Defining our Gradient Descent
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# Now we move on to actually running our operations. We will start with the operations involved in the prediction phase (i.e. the logistic regression itself).
#
# First, we need to initialize our weights and biases with zeros or random values via the inbuilt Initialization Op, <b>tf.initialize_all_variables()</b>. This Initialization Op will become a node in our computational graph, and when we put the graph into a session, then the Op will run and create the variables.

# %%
# Create a tensorflow session
sess = tf.Session()

# Initialize our weights and biases variables.
init_OP = tf.global_variables_initializer()

# Initialize all tensorflow variables
sess.run(init_OP)

# %% [markdown]
# We also want some additional operations to keep track of our model's efficiency over time. We can do this like so:

# %%
# argmax(activation_OP, 1) returns the label with the most probability
# argmax(yGold, 1) is the correct label
correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))

# If every false prediction is 0 and every true prediction is 1, the average returns us the accuracy
accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))

# Summary op for regression output
activation_summary_OP = tf.summary.histogram("output", activation_OP)

# Summary op for accuracy
accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)

# Summary op for cost
cost_summary_OP = tf.summary.scalar("cost", cost_OP)

# Summary ops to check how variables (W, b) are updating after each iteration
weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))

# Merge all summaries
merged = tf.summary.merge([activation_summary_OP, accuracy_summary_OP, cost_summary_OP, weightSummary, biasSummary])

# Summary writer
writer = tf.summary.FileWriter("summary_logs", sess.graph)

# %% [markdown]
# Now we can define and run the actual training loop, like this:

# %%
# Initialize reporting variables
cost = 0
diff = 1
epoch_values = []
accuracy_values = []
cost_values = []

# Training epochs
for i in range(numEpochs):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            train_accuracy, newCost = sess.run([accuracy_OP, cost_OP], feed_dict={X: trainX, yGold: trainY})
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            # Re-assign values for variables
            diff = abs(newCost - cost)
            cost = newCost

            #generate print statements
            print("step %d, training accuracy %g, cost %g, change in cost %g"%(i, train_accuracy, newCost, diff))


# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy_OP, 
                                                     feed_dict={X: testX, 
                                                                yGold: testY})))
# Out:
# step 0, training accuracy 0.333333, cost 34.4073, change in cost 34.4073
# step 10, training accuracy 0.464646, cost 30.2748, change in cost 4.13244
# step 20, training accuracy 0.646465, cost 28.2962, change in cost 1.97867
# step 30, training accuracy 0.646465, cost 26.6264, change in cost 1.6697
# step 40, training accuracy 0.646465, cost 25.2399, change in cost 1.38657
# step 50, training accuracy 0.646465, cost 24.0952, change in cost 1.14466
# step 60, training accuracy 0.646465, cost 23.1486, change in cost 0.946646
# step 70, training accuracy 0.646465, cost 22.3607, change in cost 0.787909
# step 80, training accuracy 0.646465, cost 21.6991, change in cost 0.661596
# step 90, training accuracy 0.646465, cost 21.138, change in cost 0.561058
# step 100, training accuracy 0.656566, cost 20.6574, change in cost 0.480648
# step 110, training accuracy 0.666667, cost 20.2415, change in cost 0.415884
# step 120, training accuracy 0.666667, cost 19.8782, change in cost 0.363283
# step 130, training accuracy 0.666667, cost 19.558, change in cost 0.320189
# step 140, training accuracy 0.666667, cost 19.2734, change in cost 0.284569
# step 150, training accuracy 0.666667, cost 19.0186, change in cost 0.254871
# step 160, training accuracy 0.676768, cost 18.7887, change in cost 0.229916
# step 170, training accuracy 0.686869, cost 18.5799, change in cost 0.208769
# step 180, training accuracy 0.686869, cost 18.3892, change in cost 0.190723
# step 190, training accuracy 0.707071, cost 18.214, change in cost 0.175207
# step 200, training accuracy 0.717172, cost 18.0522, change in cost 0.161785
# step 210, training accuracy 0.737374, cost 17.9021, change in cost 0.150095
# step 220, training accuracy 0.737374, cost 17.7622, change in cost 0.139851
# step 230, training accuracy 0.747475, cost 17.6314, change in cost 0.130835
# step 240, training accuracy 0.757576, cost 17.5085, change in cost 0.122845
# step 250, training accuracy 0.767677, cost 17.3928, change in cost 0.115736
# step 260, training accuracy 0.787879, cost 17.2834, change in cost 0.109383
# step 270, training accuracy 0.787879, cost 17.1798, change in cost 0.10367
# step 280, training accuracy 0.787879, cost 17.0812, change in cost 0.0985241
# step 290, training accuracy 0.787879, cost 16.9874, change in cost 0.0938606
# step 300, training accuracy 0.79798, cost 16.8977, change in cost 0.0896206
# step 310, training accuracy 0.79798, cost 16.812, change in cost 0.0857544
# step 320, training accuracy 0.79798, cost 16.7298, change in cost 0.0822144
# step 330, training accuracy 0.79798, cost 16.6508, change in cost 0.0789623
# step 340, training accuracy 0.79798, cost 16.5749, change in cost 0.0759659
# step 350, training accuracy 0.828283, cost 16.5017, change in cost 0.0731983
# step 360, training accuracy 0.828283, cost 16.431, change in cost 0.0706348
# step 370, training accuracy 0.838384, cost 16.3628, change in cost 0.0682545
# step 380, training accuracy 0.838384, cost 16.2967, change in cost 0.0660324
# step 390, training accuracy 0.838384, cost 16.2328, change in cost 0.0639629
# step 400, training accuracy 0.848485, cost 16.1707, change in cost 0.0620193
# step 410, training accuracy 0.848485, cost 16.1105, change in cost 0.0602036
# step 420, training accuracy 0.848485, cost 16.052, change in cost 0.0584946
# step 430, training accuracy 0.858586, cost 15.9952, change in cost 0.0568848
# step 440, training accuracy 0.868687, cost 15.9398, change in cost 0.0553646
# step 450, training accuracy 0.868687, cost 15.8859, change in cost 0.0539322
# step 460, training accuracy 0.868687, cost 15.8333, change in cost 0.0525703
# step 470, training accuracy 0.878788, cost 15.782, change in cost 0.051281
# step 480, training accuracy 0.878788, cost 15.732, change in cost 0.0500574
# step 490, training accuracy 0.878788, cost 15.6831, change in cost 0.0488911
# step 500, training accuracy 0.878788, cost 15.6353, change in cost 0.0477829
# step 510, training accuracy 0.878788, cost 15.5886, change in cost 0.0467243
# step 520, training accuracy 0.878788, cost 15.5428, change in cost 0.0457115
# step 530, training accuracy 0.878788, cost 15.4981, change in cost 0.0447445
# step 540, training accuracy 0.89899, cost 15.4543, change in cost 0.0438166
# step 550, training accuracy 0.89899, cost 15.4114, change in cost 0.0429296
# step 560, training accuracy 0.89899, cost 15.3693, change in cost 0.042078
# step 570, training accuracy 0.89899, cost 15.328, change in cost 0.0412579
# step 580, training accuracy 0.89899, cost 15.2876, change in cost 0.0404711
# step 590, training accuracy 0.909091, cost 15.2478, change in cost 0.039712
# step 600, training accuracy 0.909091, cost 15.2089, change in cost 0.0389824
# step 610, training accuracy 0.909091, cost 15.1706, change in cost 0.0382786
# step 620, training accuracy 0.909091, cost 15.133, change in cost 0.0375977
# step 630, training accuracy 0.909091, cost 15.096, change in cost 0.0369415
# step 640, training accuracy 0.909091, cost 15.0597, change in cost 0.0363083
# step 650, training accuracy 0.909091, cost 15.024, change in cost 0.0356913
# step 660, training accuracy 0.909091, cost 14.9889, change in cost 0.0350981
# step 670, training accuracy 0.909091, cost 14.9544, change in cost 0.034524
# step 680, training accuracy 0.909091, cost 14.9205, change in cost 0.0339651
# step 690, training accuracy 0.909091, cost 14.887, change in cost 0.0334244
# step 700, training accuracy 0.909091, cost 14.8541, change in cost 0.0328989
# step 710, training accuracy 0.909091, cost 14.8217, change in cost 0.0323896
# step 720, training accuracy 0.909091, cost 14.7898, change in cost 0.0318956
# step 730, training accuracy 0.909091, cost 14.7584, change in cost 0.0314131
# step 740, training accuracy 0.909091, cost 14.7275, change in cost 0.0309439
# step 750, training accuracy 0.909091, cost 14.697, change in cost 0.0304899
# step 760, training accuracy 0.909091, cost 14.667, change in cost 0.0300446
# step 770, training accuracy 0.909091, cost 14.6373, change in cost 0.0296135
# step 780, training accuracy 0.909091, cost 14.6081, change in cost 0.0291939
# step 790, training accuracy 0.909091, cost 14.5794, change in cost 0.0287828
# step 800, training accuracy 0.909091, cost 14.551, change in cost 0.0283842
# step 810, training accuracy 0.909091, cost 14.523, change in cost 0.0279932
# step 820, training accuracy 0.909091, cost 14.4954, change in cost 0.0276127
# step 830, training accuracy 0.909091, cost 14.4681, change in cost 0.0272417
# step 840, training accuracy 0.919192, cost 14.4413, change in cost 0.0268793
# step 850, training accuracy 0.919192, cost 14.4147, change in cost 0.0265226
# step 860, training accuracy 0.919192, cost 14.3885, change in cost 0.0261803
# step 870, training accuracy 0.919192, cost 14.3627, change in cost 0.0258379
# step 880, training accuracy 0.919192, cost 14.3372, change in cost 0.0255098
# step 890, training accuracy 0.919192, cost 14.312, change in cost 0.0251856
# step 900, training accuracy 0.919192, cost 14.2871, change in cost 0.024868
# step 910, training accuracy 0.919192, cost 14.2626, change in cost 0.024559
# step 920, training accuracy 0.929293, cost 14.2383, change in cost 0.0242567
# step 930, training accuracy 0.929293, cost 14.2144, change in cost 0.0239573
# step 940, training accuracy 0.929293, cost 14.1907, change in cost 0.0236702
# step 950, training accuracy 0.929293, cost 14.1673, change in cost 0.0233822
# step 960, training accuracy 0.929293, cost 14.1442, change in cost 0.0231047
# step 970, training accuracy 0.939394, cost 14.1214, change in cost 0.022831
# step 980, training accuracy 0.939394, cost 14.0988, change in cost 0.0225649
# step 990, training accuracy 0.939394, cost 14.0765, change in cost 0.0222998
# step 1000, training accuracy 0.939394, cost 14.0545, change in cost 0.0220442
# step 1010, training accuracy 0.939394, cost 14.0327, change in cost 0.0217905
# step 1020, training accuracy 0.939394, cost 14.0111, change in cost 0.0215416
# step 1030, training accuracy 0.939394, cost 13.9898, change in cost 0.0213013
# step 1040, training accuracy 0.939394, cost 13.9688, change in cost 0.02106
# step 1050, training accuracy 0.939394, cost 13.948, change in cost 0.0208263
# step 1060, training accuracy 0.939394, cost 13.9274, change in cost 0.0205965
# step 1070, training accuracy 0.939394, cost 13.907, change in cost 0.0203714
# step 1080, training accuracy 0.939394, cost 13.8868, change in cost 0.0201492
# step 1090, training accuracy 0.939394, cost 13.8669, change in cost 0.0199318
# step 1100, training accuracy 0.939394, cost 13.8472, change in cost 0.0197172
# step 1110, training accuracy 0.939394, cost 13.8277, change in cost 0.0195084
# step 1120, training accuracy 0.939394, cost 13.8084, change in cost 0.0192995
# step 1130, training accuracy 0.939394, cost 13.7893, change in cost 0.0190992
# step 1140, training accuracy 0.939394, cost 13.7704, change in cost 0.0188961
# step 1150, training accuracy 0.939394, cost 13.7517, change in cost 0.0187025
# step 1160, training accuracy 0.939394, cost 13.7332, change in cost 0.0185099
# step 1170, training accuracy 0.939394, cost 13.7149, change in cost 0.0183201
# step 1180, training accuracy 0.939394, cost 13.6967, change in cost 0.0181322
# step 1190, training accuracy 0.939394, cost 13.6788, change in cost 0.0179501
# step 1200, training accuracy 0.939394, cost 13.661, change in cost 0.0177679
# step 1210, training accuracy 0.939394, cost 13.6434, change in cost 0.0175934
# step 1220, training accuracy 0.939394, cost 13.626, change in cost 0.017416
# step 1230, training accuracy 0.939394, cost 13.6088, change in cost 0.0172453
# step 1240, training accuracy 0.939394, cost 13.5917, change in cost 0.0170755
# step 1250, training accuracy 0.939394, cost 13.5748, change in cost 0.0169096
# step 1260, training accuracy 0.939394, cost 13.558, change in cost 0.0167456
# step 1270, training accuracy 0.939394, cost 13.5414, change in cost 0.0165844
# step 1280, training accuracy 0.939394, cost 13.525, change in cost 0.0164242
# step 1290, training accuracy 0.939394, cost 13.5087, change in cost 0.0162697
# step 1300, training accuracy 0.939394, cost 13.4926, change in cost 0.0161142
# step 1310, training accuracy 0.939394, cost 13.4767, change in cost 0.0159626
# step 1320, training accuracy 0.939394, cost 13.4609, change in cost 0.0158119
# step 1330, training accuracy 0.939394, cost 13.4452, change in cost 0.0156651
# step 1340, training accuracy 0.939394, cost 13.4297, change in cost 0.015522
# step 1350, training accuracy 0.939394, cost 13.4143, change in cost 0.0153761
# step 1360, training accuracy 0.939394, cost 13.3991, change in cost 0.0152369
# step 1370, training accuracy 0.939394, cost 13.384, change in cost 0.0150995
# step 1380, training accuracy 0.939394, cost 13.369, change in cost 0.0149603
# step 1390, training accuracy 0.939394, cost 13.3542, change in cost 0.0148249
# step 1400, training accuracy 0.939394, cost 13.3395, change in cost 0.0146933
# step 1410, training accuracy 0.939394, cost 13.3249, change in cost 0.0145617
# step 1420, training accuracy 0.939394, cost 13.3105, change in cost 0.014432
# step 1430, training accuracy 0.939394, cost 13.2962, change in cost 0.0143061
# step 1440, training accuracy 0.939394, cost 13.282, change in cost 0.0141792
# step 1450, training accuracy 0.939394, cost 13.2679, change in cost 0.0140572
# step 1460, training accuracy 0.939394, cost 13.254, change in cost 0.0139341
# step 1470, training accuracy 0.939394, cost 13.2402, change in cost 0.0138111
# step 1480, training accuracy 0.939394, cost 13.2265, change in cost 0.0136938
# step 1490, training accuracy 0.939394, cost 13.2129, change in cost 0.0135765
# step 1500, training accuracy 0.939394, cost 13.1995, change in cost 0.0134602
# step 1510, training accuracy 0.939394, cost 13.1861, change in cost 0.0133467
# step 1520, training accuracy 0.939394, cost 13.1729, change in cost 0.0132351
# step 1530, training accuracy 0.939394, cost 13.1598, change in cost 0.0131235
# step 1540, training accuracy 0.939394, cost 13.1467, change in cost 0.013011
# step 1550, training accuracy 0.939394, cost 13.1338, change in cost 0.0129051
# step 1560, training accuracy 0.939394, cost 13.121, change in cost 0.0127993
# step 1570, training accuracy 0.939394, cost 13.1084, change in cost 0.0126905
# step 1580, training accuracy 0.939394, cost 13.0958, change in cost 0.0125895
# step 1590, training accuracy 0.939394, cost 13.0833, change in cost 0.0124836
# step 1600, training accuracy 0.949495, cost 13.0709, change in cost 0.0123844
# step 1610, training accuracy 0.949495, cost 13.0586, change in cost 0.0122843
# step 1620, training accuracy 0.949495, cost 13.0464, change in cost 0.0121851
# step 1630, training accuracy 0.949495, cost 13.0343, change in cost 0.0120859
# step 1640, training accuracy 0.949495, cost 13.0224, change in cost 0.0119886
# step 1650, training accuracy 0.949495, cost 13.0105, change in cost 0.0118961
# step 1660, training accuracy 0.949495, cost 12.9987, change in cost 0.0118008
# step 1670, training accuracy 0.949495, cost 12.9869, change in cost 0.0117083
# step 1680, training accuracy 0.949495, cost 12.9753, change in cost 0.0116158
# step 1690, training accuracy 0.949495, cost 12.9638, change in cost 0.0115271
# step 1700, training accuracy 0.949495, cost 12.9524, change in cost 0.0114355
# step 1710, training accuracy 0.949495, cost 12.941, change in cost 0.0113468
# step 1720, training accuracy 0.949495, cost 12.9298, change in cost 0.0112591
# step 1730, training accuracy 0.949495, cost 12.9186, change in cost 0.0111752
# step 1740, training accuracy 0.949495, cost 12.9075, change in cost 0.0110893
# step 1750, training accuracy 0.949495, cost 12.8965, change in cost 0.0110025
# step 1760, training accuracy 0.949495, cost 12.8856, change in cost 0.0109215
# step 1770, training accuracy 0.949495, cost 12.8747, change in cost 0.0108376
# step 1780, training accuracy 0.949495, cost 12.864, change in cost 0.0107574
# step 1790, training accuracy 0.949495, cost 12.8533, change in cost 0.0106773
# step 1800, training accuracy 0.949495, cost 12.8427, change in cost 0.0105963
# step 1810, training accuracy 0.949495, cost 12.8322, change in cost 0.0105181
# step 1820, training accuracy 0.949495, cost 12.8217, change in cost 0.0104418
# step 1830, training accuracy 0.949495, cost 12.8114, change in cost 0.0103636
# step 1840, training accuracy 0.949495, cost 12.8011, change in cost 0.0102892
# step 1850, training accuracy 0.949495, cost 12.7909, change in cost 0.0102119
# step 1860, training accuracy 0.949495, cost 12.7807, change in cost 0.0101395
# step 1870, training accuracy 0.949495, cost 12.7707, change in cost 0.010066
# step 1880, training accuracy 0.949495, cost 12.7607, change in cost 0.00999355
# step 1890, training accuracy 0.949495, cost 12.7508, change in cost 0.00992012
# step 1900, training accuracy 0.949495, cost 12.7409, change in cost 0.00985146
# step 1910, training accuracy 0.949495, cost 12.7311, change in cost 0.00978088
# step 1920, training accuracy 0.949495, cost 12.7214, change in cost 0.00971031
# step 1930, training accuracy 0.949495, cost 12.7118, change in cost 0.00964355
# step 1940, training accuracy 0.949495, cost 12.7022, change in cost 0.00957394
# step 1950, training accuracy 0.949495, cost 12.6927, change in cost 0.00950718
# step 1960, training accuracy 0.949495, cost 12.6833, change in cost 0.00944233
# step 1970, training accuracy 0.949495, cost 12.6739, change in cost 0.00937462
# step 1980, training accuracy 0.949495, cost 12.6646, change in cost 0.00931072
# step 1990, training accuracy 0.949495, cost 12.6553, change in cost 0.00924587
# step 2000, training accuracy 0.949495, cost 12.6461, change in cost 0.00918388
# step 2010, training accuracy 0.949495, cost 12.637, change in cost 0.00911999
# step 2020, training accuracy 0.949495, cost 12.628, change in cost 0.00905704
# step 2030, training accuracy 0.949495, cost 12.619, change in cost 0.00899506
# step 2040, training accuracy 0.949495, cost 12.61, change in cost 0.00893497
# step 2050, training accuracy 0.949495, cost 12.6012, change in cost 0.00887775
# step 2060, training accuracy 0.949495, cost 12.5923, change in cost 0.00881386
# step 2070, training accuracy 0.949495, cost 12.5836, change in cost 0.00875759
# step 2080, training accuracy 0.949495, cost 12.5749, change in cost 0.00869751
# step 2090, training accuracy 0.949495, cost 12.5662, change in cost 0.00864029
# step 2100, training accuracy 0.949495, cost 12.5577, change in cost 0.00858307
# step 2110, training accuracy 0.949495, cost 12.5491, change in cost 0.00852585
# step 2120, training accuracy 0.949495, cost 12.5407, change in cost 0.00847054
# step 2130, training accuracy 0.949495, cost 12.5322, change in cost 0.00841618
# step 2140, training accuracy 0.949495, cost 12.5239, change in cost 0.008358
# step 2150, training accuracy 0.949495, cost 12.5156, change in cost 0.00830555
# step 2160, training accuracy 0.949495, cost 12.5073, change in cost 0.00825405
# step 2170, training accuracy 0.949495, cost 12.4991, change in cost 0.00819778
# step 2180, training accuracy 0.949495, cost 12.491, change in cost 0.00814724
# step 2190, training accuracy 0.949495, cost 12.4829, change in cost 0.00809383
# step 2200, training accuracy 0.949495, cost 12.4748, change in cost 0.00804234
# step 2210, training accuracy 0.949495, cost 12.4669, change in cost 0.00799179
# step 2220, training accuracy 0.949495, cost 12.4589, change in cost 0.00794029
# step 2230, training accuracy 0.949495, cost 12.451, change in cost 0.00788975
# step 2240, training accuracy 0.949495, cost 12.4432, change in cost 0.00784016
# step 2250, training accuracy 0.949495, cost 12.4354, change in cost 0.00779247
# step 2260, training accuracy 0.949495, cost 12.4277, change in cost 0.00774193
# step 2270, training accuracy 0.949495, cost 12.42, change in cost 0.0076952
# step 2280, training accuracy 0.949495, cost 12.4123, change in cost 0.00764751
# step 2290, training accuracy 0.949495, cost 12.4047, change in cost 0.00759983
# step 2300, training accuracy 0.949495, cost 12.3972, change in cost 0.00755119
# step 2310, training accuracy 0.949495, cost 12.3897, change in cost 0.00750732
# step 2320, training accuracy 0.959596, cost 12.3822, change in cost 0.00746059
# step 2330, training accuracy 0.959596, cost 12.3748, change in cost 0.00741386
# step 2340, training accuracy 0.959596, cost 12.3674, change in cost 0.00737095
# step 2350, training accuracy 0.959596, cost 12.3601, change in cost 0.00732422
# step 2360, training accuracy 0.959596, cost 12.3528, change in cost 0.00728226
# step 2370, training accuracy 0.959596, cost 12.3456, change in cost 0.00723743
# step 2380, training accuracy 0.959596, cost 12.3384, change in cost 0.00719357
# step 2390, training accuracy 0.959596, cost 12.3312, change in cost 0.00715065
# step 2400, training accuracy 0.959596, cost 12.3241, change in cost 0.00710964
# step 2410, training accuracy 0.959596, cost 12.317, change in cost 0.00706577
# step 2420, training accuracy 0.959596, cost 12.31, change in cost 0.00702381
# step 2430, training accuracy 0.959596, cost 12.303, change in cost 0.0069828
# step 2440, training accuracy 0.959596, cost 12.2961, change in cost 0.00694275
# step 2450, training accuracy 0.959596, cost 12.2892, change in cost 0.00690079
# step 2460, training accuracy 0.959596, cost 12.2823, change in cost 0.00686264
# step 2470, training accuracy 0.959596, cost 12.2755, change in cost 0.00682068
# step 2480, training accuracy 0.959596, cost 12.2687, change in cost 0.00678062
# step 2490, training accuracy 0.959596, cost 12.262, change in cost 0.00674248
# step 2500, training accuracy 0.959596, cost 12.2553, change in cost 0.00670338
# step 2510, training accuracy 0.959596, cost 12.2486, change in cost 0.00666618
# step 2520, training accuracy 0.959596, cost 12.242, change in cost 0.00662518
# step 2530, training accuracy 0.959596, cost 12.2354, change in cost 0.00658989
# step 2540, training accuracy 0.959596, cost 12.2288, change in cost 0.00655174
# step 2550, training accuracy 0.959596, cost 12.2223, change in cost 0.0065155
# step 2560, training accuracy 0.959596, cost 12.2159, change in cost 0.00647831
# step 2570, training accuracy 0.959596, cost 12.2094, change in cost 0.00643921
# step 2580, training accuracy 0.959596, cost 12.203, change in cost 0.00640488
# step 2590, training accuracy 0.959596, cost 12.1966, change in cost 0.0063715
# step 2600, training accuracy 0.959596, cost 12.1903, change in cost 0.00633144
# step 2610, training accuracy 0.959596, cost 12.184, change in cost 0.00629997
# step 2620, training accuracy 0.959596, cost 12.1777, change in cost 0.00626373
# step 2630, training accuracy 0.959596, cost 12.1715, change in cost 0.00622845
# step 2640, training accuracy 0.959596, cost 12.1653, change in cost 0.00619507
# step 2650, training accuracy 0.959596, cost 12.1592, change in cost 0.00616264
# step 2660, training accuracy 0.959596, cost 12.153, change in cost 0.00612545
# step 2670, training accuracy 0.959596, cost 12.1469, change in cost 0.00609303
# step 2680, training accuracy 0.959596, cost 12.1409, change in cost 0.00606155
# step 2690, training accuracy 0.959596, cost 12.1349, change in cost 0.00602722
# step 2700, training accuracy 0.959596, cost 12.1289, change in cost 0.00599575
# step 2710, training accuracy 0.959596, cost 12.1229, change in cost 0.00596237
# step 2720, training accuracy 0.959596, cost 12.117, change in cost 0.00592995
# step 2730, training accuracy 0.959596, cost 12.1111, change in cost 0.00589848
# step 2740, training accuracy 0.959596, cost 12.1052, change in cost 0.00586891
# step 2750, training accuracy 0.959596, cost 12.0994, change in cost 0.00583553
# step 2760, training accuracy 0.959596, cost 12.0936, change in cost 0.00580502
# step 2770, training accuracy 0.959596, cost 12.0878, change in cost 0.0057745
# step 2780, training accuracy 0.959596, cost 12.082, change in cost 0.00574493
# step 2790, training accuracy 0.959596, cost 12.0763, change in cost 0.00571442
# step 2800, training accuracy 0.959596, cost 12.0706, change in cost 0.0056839
# step 2810, training accuracy 0.959596, cost 12.065, change in cost 0.00565434
# step 2820, training accuracy 0.959596, cost 12.0594, change in cost 0.00562572
# step 2830, training accuracy 0.959596, cost 12.0538, change in cost 0.00559425
# step 2840, training accuracy 0.959596, cost 12.0482, change in cost 0.00556564
# step 2850, training accuracy 0.959596, cost 12.0427, change in cost 0.00553894
# step 2860, training accuracy 0.959596, cost 12.0372, change in cost 0.00550747
# step 2870, training accuracy 0.959596, cost 12.0317, change in cost 0.00548267
# step 2880, training accuracy 0.959596, cost 12.0262, change in cost 0.00545311
# step 2890, training accuracy 0.959596, cost 12.0208, change in cost 0.00542736
# step 2900, training accuracy 0.959596, cost 12.0154, change in cost 0.00539589
# step 2910, training accuracy 0.959596, cost 12.01, change in cost 0.00537109
# step 2920, training accuracy 0.959596, cost 12.0047, change in cost 0.00534344
# step 2930, training accuracy 0.959596, cost 11.9994, change in cost 0.00531483
# step 2940, training accuracy 0.959596, cost 11.9941, change in cost 0.00529099
# step 2950, training accuracy 0.959596, cost 11.9888, change in cost 0.00526237
# step 2960, training accuracy 0.959596, cost 11.9836, change in cost 0.00523853
# step 2970, training accuracy 0.959596, cost 11.9784, change in cost 0.00520992
# step 2980, training accuracy 0.959596, cost 11.9732, change in cost 0.00518608
# step 2990, training accuracy 0.959596, cost 11.968, change in cost 0.00515842
# step 3000, training accuracy 0.959596, cost 11.9629, change in cost 0.00513363
# step 3010, training accuracy 0.959596, cost 11.9578, change in cost 0.00510788
# step 3020, training accuracy 0.959596, cost 11.9527, change in cost 0.00508308
# step 3030, training accuracy 0.959596, cost 11.9476, change in cost 0.0050602
# step 3040, training accuracy 0.959596, cost 11.9426, change in cost 0.00503254
# step 3050, training accuracy 0.959596, cost 11.9376, change in cost 0.00500965
# step 3060, training accuracy 0.959596, cost 11.9326, change in cost 0.00498486
# step 3070, training accuracy 0.959596, cost 11.9276, change in cost 0.00496197
# step 3080, training accuracy 0.959596, cost 11.9227, change in cost 0.00493813
# step 3090, training accuracy 0.959596, cost 11.9178, change in cost 0.00491142
# step 3100, training accuracy 0.959596, cost 11.9129, change in cost 0.00489044
# step 3110, training accuracy 0.959596, cost 11.908, change in cost 0.00486565
# step 3120, training accuracy 0.959596, cost 11.9032, change in cost 0.00484371
# step 3130, training accuracy 0.959596, cost 11.8984, change in cost 0.00481987
# step 3140, training accuracy 0.959596, cost 11.8936, change in cost 0.00479698
# step 3150, training accuracy 0.959596, cost 11.8888, change in cost 0.00477505
# step 3160, training accuracy 0.959596, cost 11.884, change in cost 0.00475216
# step 3170, training accuracy 0.959596, cost 11.8793, change in cost 0.00472927
# step 3180, training accuracy 0.959596, cost 11.8746, change in cost 0.00470638
# step 3190, training accuracy 0.959596, cost 11.8699, change in cost 0.00468636
# step 3200, training accuracy 0.959596, cost 11.8653, change in cost 0.00466347
# step 3210, training accuracy 0.959596, cost 11.8606, change in cost 0.00464153
# step 3220, training accuracy 0.959596, cost 11.856, change in cost 0.00462151
# step 3230, training accuracy 0.959596, cost 11.8514, change in cost 0.00459862
# step 3240, training accuracy 0.959596, cost 11.8468, change in cost 0.00457859
# step 3250, training accuracy 0.959596, cost 11.8423, change in cost 0.00455666
# step 3260, training accuracy 0.959596, cost 11.8377, change in cost 0.00453472
# step 3270, training accuracy 0.959596, cost 11.8332, change in cost 0.00451565
# step 3280, training accuracy 0.959596, cost 11.8287, change in cost 0.00449562
# step 3290, training accuracy 0.959596, cost 11.8242, change in cost 0.00447369
# step 3300, training accuracy 0.959596, cost 11.8198, change in cost 0.00445366
# step 3310, training accuracy 0.959596, cost 11.8154, change in cost 0.00443268
# step 3320, training accuracy 0.959596, cost 11.8109, change in cost 0.00441456
# step 3330, training accuracy 0.959596, cost 11.8066, change in cost 0.00439262
# step 3340, training accuracy 0.959596, cost 11.8022, change in cost 0.00437641
# step 3350, training accuracy 0.959596, cost 11.7978, change in cost 0.00435352
# step 3360, training accuracy 0.959596, cost 11.7935, change in cost 0.00433445
# step 3370, training accuracy 0.959596, cost 11.7892, change in cost 0.00431728
# step 3380, training accuracy 0.959596, cost 11.7849, change in cost 0.0042963
# step 3390, training accuracy 0.959596, cost 11.7806, change in cost 0.00427723
# step 3400, training accuracy 0.959596, cost 11.7763, change in cost 0.00425911
# step 3410, training accuracy 0.959596, cost 11.7721, change in cost 0.00423908
# step 3420, training accuracy 0.959596, cost 11.7679, change in cost 0.00422382
# step 3430, training accuracy 0.959596, cost 11.7637, change in cost 0.00420189
# step 3440, training accuracy 0.959596, cost 11.7595, change in cost 0.00418377
# step 3450, training accuracy 0.959596, cost 11.7553, change in cost 0.00416756
# step 3460, training accuracy 0.959596, cost 11.7512, change in cost 0.00414753
# step 3470, training accuracy 0.959596, cost 11.747, change in cost 0.00413036
# step 3480, training accuracy 0.959596, cost 11.7429, change in cost 0.00411224
# step 3490, training accuracy 0.959596, cost 11.7388, change in cost 0.00409603
# step 3500, training accuracy 0.959596, cost 11.7348, change in cost 0.00407696
# step 3510, training accuracy 0.959596, cost 11.7307, change in cost 0.00405884
# step 3520, training accuracy 0.959596, cost 11.7267, change in cost 0.00404358
# step 3530, training accuracy 0.959596, cost 11.7226, change in cost 0.00402546
# step 3540, training accuracy 0.959596, cost 11.7186, change in cost 0.00400829
# step 3550, training accuracy 0.959596, cost 11.7146, change in cost 0.00399113
# step 3560, training accuracy 0.959596, cost 11.7107, change in cost 0.00397396
# step 3570, training accuracy 0.959596, cost 11.7067, change in cost 0.00395679
# step 3580, training accuracy 0.959596, cost 11.7028, change in cost 0.00394058
# step 3590, training accuracy 0.959596, cost 11.6988, change in cost 0.00392532
# step 3600, training accuracy 0.959596, cost 11.6949, change in cost 0.0039072
# step 3610, training accuracy 0.959596, cost 11.691, change in cost 0.00389194
# step 3620, training accuracy 0.959596, cost 11.6872, change in cost 0.00387573
# step 3630, training accuracy 0.959596, cost 11.6833, change in cost 0.00385761
# step 3640, training accuracy 0.959596, cost 11.6795, change in cost 0.00384521
# step 3650, training accuracy 0.959596, cost 11.6756, change in cost 0.0038271
# step 3660, training accuracy 0.959596, cost 11.6718, change in cost 0.00381279
# step 3670, training accuracy 0.959596, cost 11.668, change in cost 0.00379562
# step 3680, training accuracy 0.959596, cost 11.6642, change in cost 0.00377941
# step 3690, training accuracy 0.959596, cost 11.6605, change in cost 0.00376606
# step 3700, training accuracy 0.959596, cost 11.6567, change in cost 0.00374985
# step 3710, training accuracy 0.959596, cost 11.653, change in cost 0.00373459
# step 3720, training accuracy 0.959596, cost 11.6493, change in cost 0.00371933
# step 3730, training accuracy 0.959596, cost 11.6456, change in cost 0.00370502
# step 3740, training accuracy 0.959596, cost 11.6419, change in cost 0.00368786
# step 3750, training accuracy 0.959596, cost 11.6382, change in cost 0.00367451
# step 3760, training accuracy 0.959596, cost 11.6345, change in cost 0.00365925
# step 3770, training accuracy 0.959596, cost 11.6309, change in cost 0.0036459
# step 3780, training accuracy 0.959596, cost 11.6273, change in cost 0.00362968
# step 3790, training accuracy 0.959596, cost 11.6237, change in cost 0.00361633
# step 3800, training accuracy 0.959596, cost 11.6201, change in cost 0.00360012
# step 3810, training accuracy 0.959596, cost 11.6165, change in cost 0.00358963
# step 3820, training accuracy 0.959596, cost 11.6129, change in cost 0.00357246
# step 3830, training accuracy 0.959596, cost 11.6093, change in cost 0.00355911
# step 3840, training accuracy 0.959596, cost 11.6058, change in cost 0.00354481
# step 3850, training accuracy 0.959596, cost 11.6023, change in cost 0.00353146
# step 3860, training accuracy 0.959596, cost 11.5987, change in cost 0.0035181
# step 3870, training accuracy 0.959596, cost 11.5952, change in cost 0.00350285
# step 3880, training accuracy 0.959596, cost 11.5917, change in cost 0.00349045
# step 3890, training accuracy 0.959596, cost 11.5883, change in cost 0.0034771
# step 3900, training accuracy 0.959596, cost 11.5848, change in cost 0.00346279
# step 3910, training accuracy 0.959596, cost 11.5814, change in cost 0.00344944
# step 3920, training accuracy 0.959596, cost 11.5779, change in cost 0.00343609
# step 3930, training accuracy 0.959596, cost 11.5745, change in cost 0.00342178
# step 3940, training accuracy 0.959596, cost 11.5711, change in cost 0.00341034
# step 3950, training accuracy 0.959596, cost 11.5677, change in cost 0.00339699
# step 3960, training accuracy 0.959596, cost 11.5643, change in cost 0.00338554
# step 3970, training accuracy 0.959596, cost 11.5609, change in cost 0.00337029
# step 3980, training accuracy 0.959596, cost 11.5576, change in cost 0.00335789
# step 3990, training accuracy 0.959596, cost 11.5542, change in cost 0.00334644
# step 4000, training accuracy 0.959596, cost 11.5509, change in cost 0.00333309
# step 4010, training accuracy 0.959596, cost 11.5476, change in cost 0.00331974
# step 4020, training accuracy 0.959596, cost 11.5443, change in cost 0.0033083
# step 4030, training accuracy 0.959596, cost 11.541, change in cost 0.00329494
# step 4040, training accuracy 0.959596, cost 11.5377, change in cost 0.00328255
# step 4050, training accuracy 0.959596, cost 11.5344, change in cost 0.00327206
# step 4060, training accuracy 0.959596, cost 11.5312, change in cost 0.0032568
# step 4070, training accuracy 0.959596, cost 11.5279, change in cost 0.00324726
# step 4080, training accuracy 0.959596, cost 11.5247, change in cost 0.00323582
# step 4090, training accuracy 0.959596, cost 11.5215, change in cost 0.00322056
# step 4100, training accuracy 0.959596, cost 11.5182, change in cost 0.00321102
# step 4110, training accuracy 0.959596, cost 11.515, change in cost 0.00319958
# step 4120, training accuracy 0.959596, cost 11.5119, change in cost 0.00318718
# step 4130, training accuracy 0.959596, cost 11.5087, change in cost 0.00317574
# step 4140, training accuracy 0.959596, cost 11.5055, change in cost 0.00316334
# step 4150, training accuracy 0.959596, cost 11.5024, change in cost 0.0031538
# step 4160, training accuracy 0.959596, cost 11.4992, change in cost 0.00314045
# step 4170, training accuracy 0.949495, cost 11.4961, change in cost 0.00312996
# step 4180, training accuracy 0.949495, cost 11.493, change in cost 0.00311756
# step 4190, training accuracy 0.949495, cost 11.4899, change in cost 0.00310612
# step 4200, training accuracy 0.949495, cost 11.4868, change in cost 0.00309658
# step 4210, training accuracy 0.949495, cost 11.4837, change in cost 0.00308418
# step 4220, training accuracy 0.949495, cost 11.4806, change in cost 0.00307369
# step 4230, training accuracy 0.949495, cost 11.4776, change in cost 0.0030632
# step 4240, training accuracy 0.949495, cost 11.4745, change in cost 0.0030508
# step 4250, training accuracy 0.949495, cost 11.4715, change in cost 0.00304031
# step 4260, training accuracy 0.949495, cost 11.4684, change in cost 0.00302982
# step 4270, training accuracy 0.949495, cost 11.4654, change in cost 0.00302029
# step 4280, training accuracy 0.949495, cost 11.4624, change in cost 0.00300789
# step 4290, training accuracy 0.949495, cost 11.4594, change in cost 0.00299835
# step 4300, training accuracy 0.949495, cost 11.4564, change in cost 0.00298786
# step 4310, training accuracy 0.949495, cost 11.4534, change in cost 0.00297546
# step 4320, training accuracy 0.949495, cost 11.4505, change in cost 0.00296688
# step 4330, training accuracy 0.949495, cost 11.4475, change in cost 0.00295734
# step 4340, training accuracy 0.949495, cost 11.4446, change in cost 0.00294495
# step 4350, training accuracy 0.949495, cost 11.4416, change in cost 0.00293636
# step 4360, training accuracy 0.949495, cost 11.4387, change in cost 0.00292587
# step 4370, training accuracy 0.949495, cost 11.4358, change in cost 0.00291538
# step 4380, training accuracy 0.949495, cost 11.4329, change in cost 0.00290489
# step 4390, training accuracy 0.949495, cost 11.43, change in cost 0.0028944
# step 4400, training accuracy 0.949495, cost 11.4271, change in cost 0.00288486
# step 4410, training accuracy 0.949495, cost 11.4242, change in cost 0.00287628
# step 4420, training accuracy 0.949495, cost 11.4214, change in cost 0.00286484
# step 4430, training accuracy 0.949495, cost 11.4185, change in cost 0.0028553
# step 4440, training accuracy 0.949495, cost 11.4157, change in cost 0.00284672
# step 4450, training accuracy 0.949495, cost 11.4128, change in cost 0.00283623
# step 4460, training accuracy 0.949495, cost 11.41, change in cost 0.00282955
# step 4470, training accuracy 0.949495, cost 11.4072, change in cost 0.00281525
# step 4480, training accuracy 0.949495, cost 11.4044, change in cost 0.00280762
# step 4490, training accuracy 0.949495, cost 11.4016, change in cost 0.00279999
# step 4500, training accuracy 0.949495, cost 11.3988, change in cost 0.00278759
# step 4510, training accuracy 0.949495, cost 11.396, change in cost 0.00278091
# step 4520, training accuracy 0.949495, cost 11.3932, change in cost 0.00277042
# step 4530, training accuracy 0.949495, cost 11.3905, change in cost 0.00276089
# step 4540, training accuracy 0.949495, cost 11.3877, change in cost 0.0027504
# step 4550, training accuracy 0.949495, cost 11.385, change in cost 0.00274467
# step 4560, training accuracy 0.949495, cost 11.3823, change in cost 0.00273323
# step 4570, training accuracy 0.949495, cost 11.3795, change in cost 0.00272274
# step 4580, training accuracy 0.949495, cost 11.3768, change in cost 0.00271797
# step 4590, training accuracy 0.949495, cost 11.3741, change in cost 0.00270557
# step 4600, training accuracy 0.949495, cost 11.3714, change in cost 0.0026989
# step 4610, training accuracy 0.949495, cost 11.3687, change in cost 0.00268841
# step 4620, training accuracy 0.949495, cost 11.366, change in cost 0.00268078
# step 4630, training accuracy 0.949495, cost 11.3634, change in cost 0.0026722
# step 4640, training accuracy 0.949495, cost 11.3607, change in cost 0.00266171
# step 4650, training accuracy 0.949495, cost 11.3581, change in cost 0.00265503
# step 4660, training accuracy 0.949495, cost 11.3554, change in cost 0.00264549
# step 4670, training accuracy 0.949495, cost 11.3528, change in cost 0.00263786
# step 4680, training accuracy 0.949495, cost 11.3501, change in cost 0.00262642
# step 4690, training accuracy 0.949495, cost 11.3475, change in cost 0.0026226
# step 4700, training accuracy 0.949495, cost 11.3449, change in cost 0.00261116
# step 4710, training accuracy 0.949495, cost 11.3423, change in cost 0.00260258
# step 4720, training accuracy 0.949495, cost 11.3397, change in cost 0.00259686
# step 4730, training accuracy 0.949495, cost 11.3371, change in cost 0.00258636
# step 4740, training accuracy 0.949495, cost 11.3345, change in cost 0.00257874
# step 4750, training accuracy 0.949495, cost 11.332, change in cost 0.00257015
# step 4760, training accuracy 0.949495, cost 11.3294, change in cost 0.00256252
# step 4770, training accuracy 0.949495, cost 11.3269, change in cost 0.00255585
# step 4780, training accuracy 0.949495, cost 11.3243, change in cost 0.00254536
# step 4790, training accuracy 0.949495, cost 11.3218, change in cost 0.00253773
# step 4800, training accuracy 0.949495, cost 11.3192, change in cost 0.00253105
# step 4810, training accuracy 0.949495, cost 11.3167, change in cost 0.00252247
# step 4820, training accuracy 0.949495, cost 11.3142, change in cost 0.00251389
# step 4830, training accuracy 0.949495, cost 11.3117, change in cost 0.00250435
# step 4840, training accuracy 0.949495, cost 11.3092, change in cost 0.00250053
# step 4850, training accuracy 0.949495, cost 11.3067, change in cost 0.002491
# step 4860, training accuracy 0.949495, cost 11.3042, change in cost 0.00248528
# step 4870, training accuracy 0.949495, cost 11.3017, change in cost 0.00247478
# step 4880, training accuracy 0.949495, cost 11.2993, change in cost 0.00246716
# step 4890, training accuracy 0.949495, cost 11.2968, change in cost 0.00245953
# step 4900, training accuracy 0.949495, cost 11.2944, change in cost 0.0024538
# step 4910, training accuracy 0.949495, cost 11.2919, change in cost 0.00244617
# step 4920, training accuracy 0.949495, cost 11.2895, change in cost 0.00243855
# step 4930, training accuracy 0.949495, cost 11.2871, change in cost 0.00242996
# step 4940, training accuracy 0.949495, cost 11.2846, change in cost 0.00242329
# step 4950, training accuracy 0.949495, cost 11.2822, change in cost 0.00241566
# step 4960, training accuracy 0.949495, cost 11.2798, change in cost 0.00240993
# step 4970, training accuracy 0.949495, cost 11.2774, change in cost 0.00239944
# step 4980, training accuracy 0.949495, cost 11.275, change in cost 0.00239372
# step 4990, training accuracy 0.949495, cost 11.2726, change in cost 0.00238705
# step 5000, training accuracy 0.949495, cost 11.2702, change in cost 0.00237942
# step 5010, training accuracy 0.949495, cost 11.2679, change in cost 0.00237274
# step 5020, training accuracy 0.949495, cost 11.2655, change in cost 0.00236511
# step 5030, training accuracy 0.949495, cost 11.2631, change in cost 0.00235844
# step 5040, training accuracy 0.949495, cost 11.2608, change in cost 0.00235081
# step 5050, training accuracy 0.949495, cost 11.2585, change in cost 0.00234509
# step 5060, training accuracy 0.949495, cost 11.2561, change in cost 0.0023365
# step 5070, training accuracy 0.949495, cost 11.2538, change in cost 0.00233078
# step 5080, training accuracy 0.949495, cost 11.2515, change in cost 0.00232506
# step 5090, training accuracy 0.949495, cost 11.2491, change in cost 0.00231457
# step 5100, training accuracy 0.949495, cost 11.2468, change in cost 0.00231075
# step 5110, training accuracy 0.949495, cost 11.2445, change in cost 0.00230312
# step 5120, training accuracy 0.949495, cost 11.2422, change in cost 0.00229549
# step 5130, training accuracy 0.949495, cost 11.2399, change in cost 0.00229073
# step 5140, training accuracy 0.949495, cost 11.2377, change in cost 0.0022831
# step 5150, training accuracy 0.949495, cost 11.2354, change in cost 0.00227642
# step 5160, training accuracy 0.949495, cost 11.2331, change in cost 0.0022707
# step 5170, training accuracy 0.949495, cost 11.2309, change in cost 0.00226212
# step 5180, training accuracy 0.949495, cost 11.2286, change in cost 0.00225735
# step 5190, training accuracy 0.949495, cost 11.2263, change in cost 0.00225067
# step 5200, training accuracy 0.949495, cost 11.2241, change in cost 0.00224209
# step 5210, training accuracy 0.949495, cost 11.2219, change in cost 0.00223827
# step 5220, training accuracy 0.949495, cost 11.2196, change in cost 0.00222969
# step 5230, training accuracy 0.949495, cost 11.2174, change in cost 0.00222492
# step 5240, training accuracy 0.949495, cost 11.2152, change in cost 0.00221825
# step 5250, training accuracy 0.949495, cost 11.213, change in cost 0.00221157
# step 5260, training accuracy 0.949495, cost 11.2108, change in cost 0.00220585
# step 5270, training accuracy 0.949495, cost 11.2086, change in cost 0.00219917
# step 5280, training accuracy 0.949495, cost 11.2064, change in cost 0.00219345
# step 5290, training accuracy 0.949495, cost 11.2042, change in cost 0.00218582
# step 5300, training accuracy 0.949495, cost 11.202, change in cost 0.00218105
# step 5310, training accuracy 0.949495, cost 11.1998, change in cost 0.00217533
# step 5320, training accuracy 0.949495, cost 11.1977, change in cost 0.00216675
# step 5330, training accuracy 0.949495, cost 11.1955, change in cost 0.00216389
# step 5340, training accuracy 0.949495, cost 11.1934, change in cost 0.00215816
# step 5350, training accuracy 0.949495, cost 11.1912, change in cost 0.00214767
# step 5360, training accuracy 0.949495, cost 11.1891, change in cost 0.00214386
# step 5370, training accuracy 0.949495, cost 11.1869, change in cost 0.00214005
# step 5380, training accuracy 0.949495, cost 11.1848, change in cost 0.00213146
# step 5390, training accuracy 0.949495, cost 11.1827, change in cost 0.00212669
# step 5400, training accuracy 0.949495, cost 11.1805, change in cost 0.00212097
# step 5410, training accuracy 0.949495, cost 11.1784, change in cost 0.0021143
# step 5420, training accuracy 0.949495, cost 11.1763, change in cost 0.00210953
# step 5430, training accuracy 0.949495, cost 11.1742, change in cost 0.00210285
# step 5440, training accuracy 0.949495, cost 11.1721, change in cost 0.00209808
# step 5450, training accuracy 0.949495, cost 11.17, change in cost 0.00209236
# step 5460, training accuracy 0.949495, cost 11.1679, change in cost 0.00208378
# step 5470, training accuracy 0.949495, cost 11.1659, change in cost 0.00208187
# step 5480, training accuracy 0.949495, cost 11.1638, change in cost 0.00207424
# step 5490, training accuracy 0.949495, cost 11.1617, change in cost 0.00206947
# step 5500, training accuracy 0.949495, cost 11.1597, change in cost 0.00206184
# step 5510, training accuracy 0.949495, cost 11.1576, change in cost 0.00205994
# step 5520, training accuracy 0.949495, cost 11.1555, change in cost 0.00205135
# step 5530, training accuracy 0.949495, cost 11.1535, change in cost 0.00204659
# step 5540, training accuracy 0.949495, cost 11.1515, change in cost 0.00204086
# step 5550, training accuracy 0.949495, cost 11.1494, change in cost 0.00203896
# step 5560, training accuracy 0.949495, cost 11.1474, change in cost 0.00202942
# step 5570, training accuracy 0.949495, cost 11.1454, change in cost 0.00202465
# step 5580, training accuracy 0.949495, cost 11.1433, change in cost 0.00201988
# step 5590, training accuracy 0.949495, cost 11.1413, change in cost 0.00201321
# step 5600, training accuracy 0.949495, cost 11.1393, change in cost 0.00201035
# step 5610, training accuracy 0.949495, cost 11.1373, change in cost 0.00200367
# step 5620, training accuracy 0.949495, cost 11.1353, change in cost 0.00199795
# step 5630, training accuracy 0.949495, cost 11.1333, change in cost 0.00199318
# step 5640, training accuracy 0.949495, cost 11.1313, change in cost 0.00198841
# step 5650, training accuracy 0.949495, cost 11.1294, change in cost 0.00198269
# step 5660, training accuracy 0.949495, cost 11.1274, change in cost 0.00197601
# step 5670, training accuracy 0.949495, cost 11.1254, change in cost 0.00197411
# step 5680, training accuracy 0.949495, cost 11.1234, change in cost 0.00196648
# step 5690, training accuracy 0.949495, cost 11.1215, change in cost 0.00196171
# step 5700, training accuracy 0.949495, cost 11.1195, change in cost 0.00195694
# step 5710, training accuracy 0.949495, cost 11.1176, change in cost 0.00195122
# step 5720, training accuracy 0.949495, cost 11.1156, change in cost 0.0019474
# step 5730, training accuracy 0.949495, cost 11.1137, change in cost 0.00194168
# step 5740, training accuracy 0.949495, cost 11.1117, change in cost 0.00193596
# step 5750, training accuracy 0.949495, cost 11.1098, change in cost 0.0019331
# step 5760, training accuracy 0.949495, cost 11.1079, change in cost 0.00192738
# step 5770, training accuracy 0.949495, cost 11.106, change in cost 0.0019207
# step 5780, training accuracy 0.949495, cost 11.104, change in cost 0.00191689
# step 5790, training accuracy 0.949495, cost 11.1021, change in cost 0.00191212
# step 5800, training accuracy 0.949495, cost 11.1002, change in cost 0.0019083
# step 5810, training accuracy 0.949495, cost 11.0983, change in cost 0.00190258
# step 5820, training accuracy 0.949495, cost 11.0964, change in cost 0.0018959
# step 5830, training accuracy 0.949495, cost 11.0945, change in cost 0.001894
# step 5840, training accuracy 0.949495, cost 11.0926, change in cost 0.00188637
# step 5850, training accuracy 0.949495, cost 11.0908, change in cost 0.00188351
# step 5860, training accuracy 0.949495, cost 11.0889, change in cost 0.00187874
# step 5870, training accuracy 0.949495, cost 11.087, change in cost 0.00187397
# step 5880, training accuracy 0.949495, cost 11.0851, change in cost 0.00186825
# step 5890, training accuracy 0.949495, cost 11.0833, change in cost 0.00186348
# step 5900, training accuracy 0.949495, cost 11.0814, change in cost 0.00186157
# step 5910, training accuracy 0.949495, cost 11.0796, change in cost 0.00185585
# step 5920, training accuracy 0.949495, cost 11.0777, change in cost 0.00184917
# step 5930, training accuracy 0.949495, cost 11.0759, change in cost 0.00184536
# step 5940, training accuracy 0.949495, cost 11.074, change in cost 0.00184155
# step 5950, training accuracy 0.949495, cost 11.0722, change in cost 0.00183678
# step 5960, training accuracy 0.949495, cost 11.0704, change in cost 0.00183201
# step 5970, training accuracy 0.949495, cost 11.0685, change in cost 0.00182724
# step 5980, training accuracy 0.949495, cost 11.0667, change in cost 0.00182438
# step 5990, training accuracy 0.949495, cost 11.0649, change in cost 0.0018177
# step 6000, training accuracy 0.949495, cost 11.0631, change in cost 0.00181389
# step 6010, training accuracy 0.949495, cost 11.0613, change in cost 0.00180817
# step 6020, training accuracy 0.949495, cost 11.0595, change in cost 0.00180721
# step 6030, training accuracy 0.949495, cost 11.0577, change in cost 0.00180054
# step 6040, training accuracy 0.949495, cost 11.0559, change in cost 0.00179577
# step 6050, training accuracy 0.949495, cost 11.0541, change in cost 0.00179386
# step 6060, training accuracy 0.949495, cost 11.0523, change in cost 0.00178719
# step 6070, training accuracy 0.949495, cost 11.0505, change in cost 0.00178528
# step 6080, training accuracy 0.949495, cost 11.0487, change in cost 0.00177765
# step 6090, training accuracy 0.949495, cost 11.0469, change in cost 0.00177479
# step 6100, training accuracy 0.949495, cost 11.0452, change in cost 0.00177097
# step 6110, training accuracy 0.949495, cost 11.0434, change in cost 0.0017662
# step 6120, training accuracy 0.949495, cost 11.0416, change in cost 0.00176048
# step 6130, training accuracy 0.939394, cost 11.0399, change in cost 0.00176048
# step 6140, training accuracy 0.939394, cost 11.0381, change in cost 0.00175285
# step 6150, training accuracy 0.939394, cost 11.0364, change in cost 0.00174809
# step 6160, training accuracy 0.939394, cost 11.0346, change in cost 0.00174618
# step 6170, training accuracy 0.939394, cost 11.0329, change in cost 0.00174141
# step 6180, training accuracy 0.939394, cost 11.0312, change in cost 0.00173759
# step 6190, training accuracy 0.939394, cost 11.0294, change in cost 0.00173187
# step 6200, training accuracy 0.939394, cost 11.0277, change in cost 0.00173092
# step 6210, training accuracy 0.939394, cost 11.026, change in cost 0.00172329
# step 6220, training accuracy 0.939394, cost 11.0242, change in cost 0.00172138
# step 6230, training accuracy 0.939394, cost 11.0225, change in cost 0.00171757
# step 6240, training accuracy 0.939394, cost 11.0208, change in cost 0.00171185
# step 6250, training accuracy 0.939394, cost 11.0191, change in cost 0.00170803
# step 6260, training accuracy 0.939394, cost 11.0174, change in cost 0.00170517
# step 6270, training accuracy 0.939394, cost 11.0157, change in cost 0.0017004
# step 6280, training accuracy 0.939394, cost 11.014, change in cost 0.00169659
# step 6290, training accuracy 0.939394, cost 11.0123, change in cost 0.00169373
# step 6300, training accuracy 0.939394, cost 11.0106, change in cost 0.00168991
# step 6310, training accuracy 0.939394, cost 11.0089, change in cost 0.00168419
# step 6320, training accuracy 0.939394, cost 11.0073, change in cost 0.00168037
# step 6330, training accuracy 0.939394, cost 11.0056, change in cost 0.00167751
# step 6340, training accuracy 0.939394, cost 11.0039, change in cost 0.0016737
# step 6350, training accuracy 0.939394, cost 11.0022, change in cost 0.00166988
# step 6360, training accuracy 0.939394, cost 11.0006, change in cost 0.00166512
# step 6370, training accuracy 0.939394, cost 10.9989, change in cost 0.00166225
# step 6380, training accuracy 0.939394, cost 10.9973, change in cost 0.00165749
# step 6390, training accuracy 0.939394, cost 10.9956, change in cost 0.00165558
# step 6400, training accuracy 0.939394, cost 10.9939, change in cost 0.00164986
# step 6410, training accuracy 0.939394, cost 10.9923, change in cost 0.00164509
# step 6420, training accuracy 0.939394, cost 10.9907, change in cost 0.00164413
# step 6430, training accuracy 0.939394, cost 10.989, change in cost 0.00164032
# step 6440, training accuracy 0.939394, cost 10.9874, change in cost 0.0016346
# step 6450, training accuracy 0.939394, cost 10.9858, change in cost 0.00163174
# step 6460, training accuracy 0.939394, cost 10.9841, change in cost 0.00162983
# step 6470, training accuracy 0.939394, cost 10.9825, change in cost 0.00162411
# step 6480, training accuracy 0.939394, cost 10.9809, change in cost 0.00162125
# step 6490, training accuracy 0.939394, cost 10.9793, change in cost 0.00161743
# step 6500, training accuracy 0.939394, cost 10.9776, change in cost 0.00161266
# step 6510, training accuracy 0.939394, cost 10.976, change in cost 0.00161076
# step 6520, training accuracy 0.939394, cost 10.9744, change in cost 0.00160599
# step 6530, training accuracy 0.939394, cost 10.9728, change in cost 0.00160313
# step 6540, training accuracy 0.939394, cost 10.9712, change in cost 0.00159931
# step 6550, training accuracy 0.939394, cost 10.9696, change in cost 0.00159645
# step 6560, training accuracy 0.939394, cost 10.968, change in cost 0.00159264
# step 6570, training accuracy 0.939394, cost 10.9664, change in cost 0.00158882
# step 6580, training accuracy 0.939394, cost 10.9649, change in cost 0.00158501
# step 6590, training accuracy 0.939394, cost 10.9633, change in cost 0.00158119
# step 6600, training accuracy 0.939394, cost 10.9617, change in cost 0.00157928
# step 6610, training accuracy 0.939394, cost 10.9601, change in cost 0.00157452
# step 6620, training accuracy 0.939394, cost 10.9586, change in cost 0.0015707
# step 6630, training accuracy 0.939394, cost 10.957, change in cost 0.00156784
# step 6640, training accuracy 0.939394, cost 10.9554, change in cost 0.00156593
# step 6650, training accuracy 0.939394, cost 10.9539, change in cost 0.00155926
# step 6660, training accuracy 0.939394, cost 10.9523, change in cost 0.0015583
# step 6670, training accuracy 0.939394, cost 10.9508, change in cost 0.0015564
# step 6680, training accuracy 0.939394, cost 10.9492, change in cost 0.00155067
# step 6690, training accuracy 0.939394, cost 10.9477, change in cost 0.00154781
# step 6700, training accuracy 0.939394, cost 10.9461, change in cost 0.001544
# step 6710, training accuracy 0.939394, cost 10.9446, change in cost 0.00154018
# step 6720, training accuracy 0.939394, cost 10.943, change in cost 0.00153923
# step 6730, training accuracy 0.939394, cost 10.9415, change in cost 0.0015316
# step 6740, training accuracy 0.939394, cost 10.94, change in cost 0.00153351
# step 6750, training accuracy 0.939394, cost 10.9384, change in cost 0.00152683
# step 6760, training accuracy 0.939394, cost 10.9369, change in cost 0.00152588
# step 6770, training accuracy 0.939394, cost 10.9354, change in cost 0.0015192
# step 6780, training accuracy 0.939394, cost 10.9339, change in cost 0.00151825
# step 6790, training accuracy 0.939394, cost 10.9324, change in cost 0.00151539
# step 6800, training accuracy 0.939394, cost 10.9308, change in cost 0.00151157
# step 6810, training accuracy 0.939394, cost 10.9293, change in cost 0.00150967
# step 6820, training accuracy 0.939394, cost 10.9278, change in cost 0.0015049
# step 6830, training accuracy 0.939394, cost 10.9263, change in cost 0.00150108
# step 6840, training accuracy 0.939394, cost 10.9248, change in cost 0.00149918
# step 6850, training accuracy 0.939394, cost 10.9233, change in cost 0.00149632
# step 6860, training accuracy 0.939394, cost 10.9218, change in cost 0.0014925
# step 6870, training accuracy 0.939394, cost 10.9204, change in cost 0.00148869
# step 6880, training accuracy 0.939394, cost 10.9189, change in cost 0.00148678
# step 6890, training accuracy 0.939394, cost 10.9174, change in cost 0.00148392
# step 6900, training accuracy 0.939394, cost 10.9159, change in cost 0.0014801
# step 6910, training accuracy 0.939394, cost 10.9144, change in cost 0.00147724
# step 6920, training accuracy 0.939394, cost 10.913, change in cost 0.00147438
# step 6930, training accuracy 0.939394, cost 10.9115, change in cost 0.00146961
# step 6940, training accuracy 0.939394, cost 10.91, change in cost 0.0014677
# step 6950, training accuracy 0.939394, cost 10.9085, change in cost 0.0014658
# step 6960, training accuracy 0.939394, cost 10.9071, change in cost 0.00146198
# step 6970, training accuracy 0.939394, cost 10.9056, change in cost 0.00145912
# step 6980, training accuracy 0.939394, cost 10.9042, change in cost 0.00145435
# step 6990, training accuracy 0.939394, cost 10.9027, change in cost 0.00145435
# final accuracy on test set: 1.0

# %% [markdown]
# <b>Why don't we plot the cost to see how it behaves?</b>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#plt.plot([np.mean(cost_values[i-50:i]) for i in range(len(cost_values))])
plt.plot([np.mean(cost_values[i-1000:i]) for i in range(len(cost_values))])
plt.show()

# %% [markdown]
# Assuming no parameters were changed, you should reach a peak accuracy of 90% at the end of training, which is commendable. Try changing the parameters such as the length of training, and maybe some operations to see how the model behaves. Does it take much longer? How is the performance?

# %% [markdown]
# <hr>

# %% [markdown]
# ## Want to learn more?
#
# Running deep learning programs usually needs a high performance platform. __PowerAI__ speeds up deep learning and AI. Built on IBM’s Power Systems, __PowerAI__ is a scalable software platform that accelerates deep learning and AI with blazing performance for individual users or enterprises. The __PowerAI__ platform supports popular machine learning libraries and dependencies including TensorFlow, Caffe, Torch, and Theano. You can use [PowerAI on IMB Cloud](https://cocl.us/ML0120EN_PAI).
#
# Also, you can use __Watson Studio__ to run these notebooks faster with bigger datasets.__Watson Studio__ is IBM’s leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, __Watson Studio__ enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of __Watson Studio__ users today with a free account at [Watson Studio](https://cocl.us/ML0120EN_DSX).This is the end of this lesson. Thank you for reading this notebook, and good luck on your studies.

# %% [markdown]
# ### Thanks for completing this lesson!
#
# This is the end of **Logistic Regression with TensorFlow** notebook. Hopefully, now you have a deeper understanding of Logistic Regression and how its structure and flow work. Thank you for reading this notebook and good luck on your studies.

# %% [markdown]
# Created by: <a href="https://br.linkedin.com/in/walter-gomes-de-amorim-junior-624726121">Saeed Aghabozorgi</a> , <a href="https://br.linkedin.com/in/walter-gomes-de-amorim-junior-624726121">Walter Gomes de Amorim Junior</a> ,  Victor Barros Costa

# %% [markdown]
# <hr>
#
# Copyright &copy; 2018 [Cognitive Class](https://cocl.us/DX0108EN_CC). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
